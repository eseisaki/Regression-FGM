# %%
# full screen layout
from IPython.core.display import display, HTML
display(HTML(
    '<style>'
        '#notebook { padding-top:0px !important; } ' 
        '.container { width:100% !important; } '
        '.end_space { min-height:0px !important; } '
        'td {font-size: 25px}'
    '</style>'
))
# Out:
# <style>#notebook { padding-top:0px !important; } .container { width:100% !important; } .end_space { min-height:0px !important; } td {font-size: 25px}</style>

# %%
# import libraries
import warnings
warnings.filterwarnings("ignore")
import constants as const
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# useful functions for plotting
def create_plot(x,y,x_title,y_title,full_title, fig_name):
    
    fig,ax = plt.subplots(figsize = (18,14))
    ax.plot(x,y,color ='red',linewidth=3)
    
    ax.grid(True,linestyle='dashdot', color='grey')
    ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)
    
    ax.set_ylim(0,20)
    
    ax.set_xlabel(x_title,fontsize=20)
    ax.set_ylabel(y_title,fontsize=20)
    ax.set_title(full_title,fontsize=25,pad =15)

    plt.savefig(fig_name)
    
def create_merged_plot(y1,y2,x,x_title,y_title,full_title,cases, ylim, fig_name):
    
    fig,ax = plt.subplots(figsize = (18,14))
    
    ax.plot(x,y1,linewidth=3, label=cases[0],color = '#d62728')
    ax.plot(x,y2,linewidth=3, label=cases[1],color = '#17becf')
    plt.fill_between(x, y1, y2, color="grey", alpha="0.3")
    
    ax.legend(fontsize=20)
    ax.grid(True,linestyle='dashdot', color='grey')
    ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)
    
    #ax.set_xlim(0, 1000)
    if ylim is not None:
        ax.set_ylim(ylim,100)
        

    ax.set_xlabel(x_title,fontsize=20)
    ax.set_ylabel(y_title,fontsize=20)
    ax.set_title(full_title,fontsize=25,pad =15)
    
    plt.savefig(fig_name )

# %%
# useful functions for data evaluation
def import_metric(file, name):
    df = pd.read_csv(file,names=[name,"time"])
    return df

def align_axis(arr1,arr2,head1,head2):
    merged = pd.merge(arr1, arr2,on='time',how='outer').sort_values(by='time')
    merged[head2].fillna(method='ffill')
    merged[head1].fillna(method='ffill')
    
    return merged

def plot_metrics(arr1,arr2,head1,head2,title,ylim, fig_name):
    merged = pd.merge(arr1, arr2,on='time',how='outer').sort_values(by='time')

    x_axis = merged['time']
    y1 = merged[head1].fillna(method='ffill')
    y2 = merged[head2].fillna(method='ffill')

    create_merged_plot(y1=y1,
                       y2=y2,
                       x=x_axis,
                       x_title='unit time',
                       y_title='model error',
                       full_title=title,
                       cases=[head1,head2],
                       ylim=ylim,
                       fig_name=fig_name)

# %%
# import metrics
MAE_central = import_metric("tests/centralized_fixed_points_30000_feat_10_K_10_win_2000_error_0.01MAE.csv","MAE_central")
#R_central = import_metric("tests/centralized__fixed_points_30000_feat_10_K_10_win_1500_error_1.4R.csv","R_central")
MAE_gm1=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.01MAE.csv","MAE_gm1")
MAE_gm2=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.05MAE.csv","MAE_gm2")
MAE_gm3=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.1MAE.csv","MAE_gm3")
MAE_gm4=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.5MAE.csv","MAE_gm4")
MAE_gm5=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_1MAE.csv","MAE_gm5")
MAE_gm6=import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_2MAE.csv","MAE_gm6")
#R_gm =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_1500_error_1.4R.csv","R_gm")
ROUNDS_gm1 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.01ROUNDS.csv","ROUNDS_gm1")
ROUNDS_gm2 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.05ROUNDS.csv","ROUNDS_gm2")
ROUNDS_gm3 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.1ROUNDS.csv","ROUNDS_gm3")
ROUNDS_gm4 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_0.5ROUNDS.csv","ROUNDS_gm4")
ROUNDS_gm5 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_1ROUNDS.csv","ROUNDS_gm5")
ROUNDS_gm6 =import_metric("tests/gm_fixed_points_30000_feat_10_K_10_win_2000_error_2ROUNDS.csv","ROUNDS_gm6")
                         

MAE_fgm1=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.01MAE.csv","MAE_fgm1")
MAE_fgm2=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.05MAE.csv","MAE_fgm2")
MAE_fgm3=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.1MAE.csv","MAE_fgm3")
MAE_fgm4=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.5MAE.csv","MAE_fgm4")
MAE_fgm5=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_1MAE.csv","MAE_fgm5")
MAE_fgm6=import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_2MAE.csv","MAE_fgm6")
#R_fgm =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_1500_error_1.4R.csv","R_fgm")
ROUNDS_fgm1 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.01ROUNDS.csv","ROUNDS_fgm1")
ROUNDS_fgm2 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.05ROUNDS.csv","ROUNDS_fgm2")
ROUNDS_fgm3 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.1ROUNDS.csv","ROUNDS_fgm3")
ROUNDS_fgm4 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_0.5ROUNDS.csv","ROUNDS_fgm4")
ROUNDS_fgm5 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_1ROUNDS.csv","ROUNDS_fgm5")
ROUNDS_fgm6 =import_metric("tests/fgm_fixed_points_30000_feat_10_K_10_win_2000_error_2ROUNDS.csv","ROUNDS_fgm6")

# %%
fig,ax = plt.subplots(figsize = (18,14))
ax.plot(MAE_central["time"],MAE_central["MAE_central"], label="centralized")
ax.plot(MAE_gm1["time"],MAE_gm1['MAE_gm1'].fillna(method='ffill'), label="thres=0.01")
ax.plot(MAE_gm2["time"],MAE_gm2['MAE_gm2'].fillna(method='ffill'), label="thres=0.05")
ax.plot(MAE_gm3["time"],MAE_gm3['MAE_gm3'].fillna(method='ffill'), label="thres=0.1")
ax.plot(MAE_gm4["time"],MAE_gm4['MAE_gm4'].fillna(method='ffill'), label="thres=0.5")
ax.plot(MAE_gm5["time"],MAE_gm5['MAE_gm5'].fillna(method='ffill'), label="thres=1")
ax.plot(MAE_gm6["time"],MAE_gm6['MAE_gm6'].fillna(method='ffill'), label="thres=2")

ax.legend(fontsize=20)
ax.grid(True,linestyle='dashdot', color='grey')
ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)

ax.set_xlabel("time",fontsize=20)
ax.set_ylabel("MAE",fontsize=20)
ax.set_title("Error of GM",fontsize=25,pad =15)

ax.set_xlim(0,50)
# Out:
# (0, 50)

# %%
fig,ax = plt.subplots(figsize = (18,14))
ax.plot(MAE_central["time"],MAE_central["MAE_central"], label="centralized")
ax.plot(MAE_fgm1["time"],MAE_fgm1['MAE_fgm1'].fillna(method='ffill'), label="thres=0.01")
ax.plot(MAE_fgm2["time"],MAE_fgm2['MAE_fgm2'].fillna(method='ffill'), label="thres=0.05")
ax.plot(MAE_fgm3["time"],MAE_fgm3['MAE_fgm3'].fillna(method='ffill'), label="thres=0.1")
ax.plot(MAE_fgm4["time"],MAE_fgm4['MAE_fgm4'].fillna(method='ffill'), label="thres=0.5")
ax.plot(MAE_fgm5["time"],MAE_fgm5['MAE_fgm5'].fillna(method='ffill'), label="thres=1")
ax.plot(MAE_fgm6["time"],MAE_fgm6['MAE_fgm6'].fillna(method='ffill'), label="thres=2")

ax.legend(fontsize=20)
ax.grid(True,linestyle='dashdot', color='grey')
ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)

ax.set_xlabel("time",fontsize=20)
ax.set_ylabel("MAE",fontsize=20)
ax.set_title("Error of FGM",fontsize=25,pad =15)

ax.set_xlim(0,50)
# Out:
# (0, 50)

# %%
fig,ax = plt.subplots(figsize = (18,14))
ax.plot(ROUNDS_gm1['time'],ROUNDS_gm1['ROUNDS_gm1'], label="thres=0.01")
ax.plot(ROUNDS_gm2['time'],ROUNDS_gm2['ROUNDS_gm2'], label="thres=0.05")
ax.plot(ROUNDS_gm3['time'],ROUNDS_gm3['ROUNDS_gm3'], label="thres=0.1")
ax.plot(ROUNDS_gm4['time'],ROUNDS_gm4['ROUNDS_gm4'], label="thres=0.5")
ax.plot(ROUNDS_gm5['time'],ROUNDS_gm5['ROUNDS_gm5'], label="thres=1")
ax.plot(ROUNDS_gm6['time'],ROUNDS_gm6['ROUNDS_gm6'], label="thres=2")

ax.legend(fontsize=20)
ax.grid(True,linestyle='dashdot', color='grey')
ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)

ax.set_xlabel("time",fontsize=20)
ax.set_ylabel("ROUNDS",fontsize=20)
ax.set_title("ROUNDS of GM",fontsize=25,pad =15)

ax.set_xlim(0,10000)
# Out:
# (0, 10000)

# %%
fig,ax = plt.subplots(figsize = (18,14))
ax.plot(ROUNDS_fgm1['time'],ROUNDS_fgm1['ROUNDS_fgm1'], label="thres=0.01")
ax.plot(ROUNDS_fgm2['time'],ROUNDS_fgm2['ROUNDS_fgm2'], label="thres=0.05")
ax.plot(ROUNDS_fgm3['time'],ROUNDS_fgm3['ROUNDS_fgm3'], label="thres=0.1")
ax.plot(ROUNDS_fgm4['time'],ROUNDS_fgm4['ROUNDS_fgm4'], label="thres=0.5")
ax.plot(ROUNDS_fgm5['time'],ROUNDS_fgm5['ROUNDS_fgm5'], label="thres=1")
ax.plot(ROUNDS_fgm6['time'],ROUNDS_fgm6['ROUNDS_fgm6'], label="thres=2")

ax.legend(fontsize=20)
ax.grid(True,linestyle='dashdot', color='grey')
ax.tick_params(labelcolor='red', labelsize=15,pad=10,direction = 'inout', width=3)

ax.set_xlabel("time",fontsize=20)
ax.set_ylabel("ROUNDS",fontsize=20)
ax.set_title("ROUNDS of FGM",fontsize=25,pad =15)

ax.set_xlim(0,10000)
# Out:
# (0, 10000)
